# %% [markdown]
# <a href="https://colab.research.google.com/github/unitxero/Data_Analysis_MC/blob/main/Day_7_Group_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Part 1

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/property.csv')

# %%
data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           8 non-null      float64
#  1   ST_NUM        7 non-null      float64
#  2   ST_NAME       9 non-null      object
#  3   OWN_OCCUPIED  8 non-null      object
#  4   NUM_BEDROOMS  7 non-null      object
#  5   NUM_BATH      8 non-null      object
#  6   SQ_FT         8 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 632.0+ bytes

# %%
# putting new pid 
new_PID = data['PID'].fillna(100005000.0)

# %%
data.drop(labels = 'PID', axis = 1, inplace = True)

# %%
data['PID'] = new_PID

# %%
# adding PID as the index
data.set_index('PID', inplace = True)

# %%
data2 = data

# %%
data2
# Out:
#              ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0      PUTNAM            Y            3        1  1000
# 100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 100004000.0   201.0    BERKELEY           12            1      NaN   700
# 100005000.0   203.0    BERKELEY            Y            3        2  1600
# 100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 100008000.0   213.0     TREMONT            Y            1        1   NaN
# 100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
#data.iloc[6]

df_no_wash = data2.drop([100007000.0], axis = 0)

# %%
df_no_wash
# Out:
#              ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0     PUTNAM            Y            3        1  1000
# 100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 100003000.0     NaN  LEXINGTON            N          NaN        1   850
# 100004000.0   201.0   BERKELEY           12            1      NaN   700
# 100005000.0   203.0   BERKELEY            Y            3        2  1600
# 100006000.0   207.0   BERKELEY            Y          NaN        1   800
# 100008000.0   213.0    TREMONT            Y            1        1   NaN
# 100009000.0   215.0    TREMONT            Y           na        2  1800

# %%
df_no_wash
# Out:
#              ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0     PUTNAM            Y            3        1  1000
# 100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 100003000.0     NaN  LEXINGTON            N          NaN        1   850
# 100004000.0   201.0   BERKELEY           12            1      NaN   700
# 100005000.0   203.0   BERKELEY            Y            3        2  1600
# 100006000.0   207.0   BERKELEY            Y          NaN        1   800
# 100008000.0   213.0    TREMONT            Y            1        1   NaN
# 100009000.0   215.0    TREMONT            Y           na        2  1800

# %%
df_no_wash['SQ_FT'].str.isnumeric()
# Out:
# PID
# 100001000.0     True
# 100002000.0    False
# 100003000.0     True
# 100004000.0     True
# 100005000.0     True
# 100006000.0     True
# 100008000.0      NaN
# 100009000.0     True
# Name: SQ_FT, dtype: object

# %%
df_no_wash_na = df_no_wash.fillna(value= 0)
df_no_wash_na
# Out:
#              ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0     PUTNAM            Y            3        1  1000
# 100002000.0   197.0  LEXINGTON            N            3      1.5    --
# 100003000.0     0.0  LEXINGTON            N            0        1   850
# 100004000.0   201.0   BERKELEY           12            1        0   700
# 100005000.0   203.0   BERKELEY            Y            3        2  1600
# 100006000.0   207.0   BERKELEY            Y            0        1   800
# 100008000.0   213.0    TREMONT            Y            1        1     0
# 100009000.0   215.0    TREMONT            Y           na        2  1800

# %%
df_no_wash_na['SQ_FT'][100002000.0] = 0
# Out:
# 0

# %%
df_no_wash_na
# Out:
#              ST_NUM    ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# PID
# 100001000.0   104.0     PUTNAM            Y            3        1  1000
# 100002000.0   197.0  LEXINGTON            N            3      1.5     0
# 100003000.0     0.0  LEXINGTON            N            0        1   850
# 100004000.0   201.0   BERKELEY           12            1        0   700
# 100005000.0   203.0   BERKELEY            Y            3        2  1600
# 100006000.0   207.0   BERKELEY            Y            0        1   800
# 100008000.0   213.0    TREMONT            Y            1        1     0
# 100009000.0   215.0    TREMONT            Y           na        2  1800

# %%
sqft_sum = df_no_wash_na[['ST_NAME', 'SQ_FT']]

# %%
sqft_sum
# Out:
#                ST_NAME SQ_FT
# PID
# 100001000.0     PUTNAM  1000
# 100002000.0  LEXINGTON     0
# 100003000.0  LEXINGTON   850
# 100004000.0   BERKELEY   700
# 100005000.0   BERKELEY  1600
# 100006000.0   BERKELEY   800
# 100008000.0    TREMONT     0
# 100009000.0    TREMONT  1800

# %%
sqft_sum.astype({'SQ_FT': 'int32'}).dtypes
# Out:
# ST_NAME    object
# SQ_FT       int32
# dtype: object

# %%
sq_ft_grouping = sqft_sum.groupby(by= ['ST_NAME'])
st_name_all= sq_ft_grouping.agg({'SQ_FT':"sum"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-0330391e9c81> in <module>()
#       1 sq_ft_grouping = sqft_sum.groupby(by= ['ST_NAME'])
# ----> 2 st_name_all= sq_ft_grouping.agg({'SQ_FT':"sum"})
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     949         func = maybe_mangle_lambdas(func)
#     950
# --> 951         result, how = self._aggregate(func, *args, **kwargs)
#     952         if how is None:
#     953             return result
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     414
#     415                 try:
# --> 416                     result = _agg(arg, _agg_1dim)
#     417                 except SpecificationError:
#     418
#
# ...

# %% [markdown]
# # Part 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_election = pd.read_csv('https://raw.githubusercontent.com/glopez21/ML-Data/main/2020%20November%20General%20Election%20-%20Turnout%20Rates.csv')

# %%
# preview of the data
df_election.head()
# Out:
#            State  ... State Abv
# 0  United States  ...       NaN
# 1        Alabama  ...        AL
# 2         Alaska  ...        AK
# 3        Arizona  ...        AZ
# 4       Arkansas  ...        AR
#
# [5 rows x 15 columns]

# %%
df_election.columns
# Out:
# Index(['State', 'Source', 'Official/Unofficial',
#        'Total Ballots Counted (Estimate)',
#        'Vote for Highest Office (President)', 'VEP Turnout Rate',
#        'Voting-Eligible Population (VEP)', 'Voting-Age Population (VAP)',
#        '% Non-citizen', 'Prison', 'Probation', 'Parole',
#        'Total Ineligible Felon', 'Overseas Eligible', 'State Abv'],
#       dtype='object')

# %%
df_election

# %%
df_election.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                52 non-null     object
#  1   Source                               40 non-null     object
#  2   Official/Unofficial                  25 non-null     object
#  3   Total Ballots Counted (Estimate)     52 non-null     object
#  4   Vote for Highest Office (President)  24 non-null     object
#  5   VEP Turnout Rate                     52 non-null     object
#  6   Voting-Eligible Population (VEP)     52 non-null     object
#  7   Voting-Age Population (VAP)          52 non-null     object
#  8   % Non-citizen                        52 non-null     object
#  9   Prison                               52 non-null     object
#  10  Probation                            52 non-null     object
# ...

# %%
df_election.iloc[10]
# Out:
# State                                                                            Florida
# Source                                 https://floridaelectionwatch.gov/CountyReporti...
# Official/Unofficial                                                                  NaN
# Total Ballots Counted (Estimate)                                              11,150,000
# Vote for Highest Office (President)                                                  NaN
# VEP Turnout Rate                                                                   71.7%
# Voting-Eligible Population (VEP)                                              15,551,739
# Voting-Age Population (VAP)                                                   17,543,341
# % Non-citizen                                                                      10.1%
# Prison                                                                            91,674
# ...

# %%
df_graph = df_election[['State',
                       'Voting-Eligible Population (VEP)',
                       'Voting-Age Population (VAP)',]]

# %%
xaxis_1 = df_graph['State']

# %%
yaxis_1 = df_graph['Voting-Eligible Population (VEP)']
yaxis_2 = df_graph['Voting-Age Population (VAP)']

# %%
df_graph.dtypes
# Out:
# State                               object
# Voting-Eligible Population (VEP)    object
# Voting-Age Population (VAP)         object
# dtype: object

# %%
df_graph.groupby(['State'])['Voting-Eligible Population (VEP)'].plot(kind = 'bar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     858             try:
# --> 859                 result = self._python_apply_general(f, self._selected_obj)
#     860             except TypeError:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#     891         """
# --> 892         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#     893
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     219             group_axes = group.axes
# --> 220             res = f(group)
#     221             if not _is_indexed_like(res, group_axes):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in f(self)
# ...
